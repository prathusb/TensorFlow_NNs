# %% [markdown]
# # Chapter 11 Exercises

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "deep"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %%
import tensorflow as tf

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
X_train = X_train.astype(np.float32).reshape(-1, 28*28) / 255.0
X_test = X_test.astype(np.float32).reshape(-1, 28*28) / 255.0
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)
X_valid, X_train = X_train[:5000], X_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]

# %% [markdown]
# ## Problem 8:

# %%
reset_graph()

he_init = tf.variance_scaling_initializer()

# Condensed form of the above code
def dnn(inputs,n_hidden_layers,n_per_h_layer,n_outputs,activation=tf.nn.elu,initializer=he_init,seed=42,learning_rate=0.01):
    # For Chapter 11 #8a
    with tf.name_scope("dnn"):
        training = tf.placeholder_with_default(False, shape=(), name='training')
        for layer_num in range(n_hidden_layers):
            inputs = tf.layers.dense(inputs, n_per_h_layer, 
                                     activation=activation, kernel_initializer=initializer, name="hidden%d" % (layer_num+1))
            # Batch Normalization hidden layers
            bn = tf.layers.batch_normalization(inputs,training=training,momentum=0.9,name="hidden%d" % (layer_num+1))
        #outputs = inputs
        outputs = bn
        logits = tf.layers.dense(outputs, n_outputs, kernel_initializer=he_init, name="logits")
        y_prob = tf.nn.softmax(logits, name="y_prob")
    # For #8b
    with tf.name_scope("loss"):
        xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
        loss = tf.reduce_mean(xentropy, name="loss")
    with tf.name_scope("train"):
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        training_op = optimizer.minimize(loss, name="training_op")
        loss_summary = tf.summary.scalar('log_loss', loss)
    with tf.name_scope("eval"):
        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
    with tf.name_scope("init"):
        init = tf.global_variables_initializer()
    with tf.name_scope("save"):
        saver = tf.train.Saver()
    return y_prob, logits, loss, training_op, loss_summary, accuracy, init, saver

# %%
# For TensorBoard
from datetime import datetime

def log_dir(prefix=""):
    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    root_logdir = "tf_logs"
    if prefix:
        prefix += "-"
    name = prefix + "run-" + now
    return "{}/{}/".format(root_logdir, name)

# %%
# Graph for TensorBoard
# (not using an enhanced X, using X from before)
n_inputs = 28*28  # MNIST
n_hidden_layers = 5
n_per_h_layer = 100
n_outputs = 5
logdir = log_dir("dnn11")

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int32, shape=(None), name="y")
# inputs = X ???
y_prob, logits, loss, training_op, loss_summary, accuracy, init, saver = dnn(X,n_hidden_layers,n_per_h_layer,n_outputs)

file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

# %%
# For 8b: 0 to 4
X_train1 = X_train[y_train < 5]
y_train1 = y_train[y_train < 5]
X_valid1 = X_valid[y_valid < 5]
y_valid1 = y_valid[y_valid < 5]
X_test1 = X_test[y_test < 5]
y_test1 = y_test[y_test < 5]

# %%
n_epochs = 1000
batch_size = 20

max_checks_without_progress = 20
checks_without_progress = 0
best_loss = np.infty

checkpoint_path = "/tmp/dnn11_0_to_4.ckpt"
checkpoint_epoch_path = checkpoint_path + ".epoch"
final_model_path = "./dnn11_0_to_4"

# %%
def shuffle_batch(X, y, batch_size):
    rnd_idx = np.random.permutation(len(X))
    n_batches = len(X) // batch_size
    for batch_idx in np.array_split(rnd_idx, n_batches):
        X_batch, y_batch = X[batch_idx], y[batch_idx]
        yield X_batch, y_batch

# %%
with tf.Session() as sess:
    if os.path.isfile(checkpoint_epoch_path):
        # if the checkpoint file exists, restore the model and load the epoch number
        with open(checkpoint_epoch_path, "rb") as f:
            start_epoch = int(f.read())
        print("Training was interrupted. Continuing at epoch", start_epoch)
        saver.restore(sess, checkpoint_path)
    else:
        start_epoch = 0
        sess.run(init)
        
    for epoch in range(n_epochs):
        for X_batch, y_batch in shuffle_batch(X_train1, y_train1, batch_size):
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        #acc_batch = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        #acc_val = accuracy.eval(feed_dict={X: X_valid1, y: y_valid1})
        loss_val, acc_val = sess.run([loss, accuracy], feed_dict={X: X_valid1, y: y_valid1})
        if loss_val < best_loss:
            save_path = saver.save(sess, "./dnn11_0_to_4.ckpt")
            best_loss = loss_val
            checks_without_progress = 0
        else:
            checks_without_progress += 1
            if checks_without_progress > max_checks_without_progress:
                print("Early stopping!")
                break
        save_path = saver.save(sess, "./dnn11_0_to_4.epoch")
        print("{}\tValidation loss: {:.6f}\tBest loss: {:.6f}\tAccuracy: {:.2f}%".format(
            epoch, loss_val, best_loss, acc_val * 100))

with tf.Session() as sess:
    saver.restore(sess, "./dnn11_0_to_4.ckpt")
    acc_test = accuracy.eval(feed_dict={X: X_test1, y: y_test1})
    print("Final test accuracy: {:.2f}%".format(acc_test * 100))

    save_path = saver.save(sess, "./my_dnn11_0_to_4_final.ckpt")
# Out:
# 0	Validation loss: 0.095959	Best loss: 0.095959	Accuracy: 97.54%
# 1	Validation loss: 0.100916	Best loss: 0.095959	Accuracy: 97.93%
# 2	Validation loss: 0.561315	Best loss: 0.095959	Accuracy: 68.45%
# 3	Validation loss: 0.126042	Best loss: 0.095959	Accuracy: 97.73%
# 4	Validation loss: 0.196491	Best loss: 0.095959	Accuracy: 96.17%
# 5	Validation loss: 0.209917	Best loss: 0.095959	Accuracy: 97.42%
# 6	Validation loss: 0.146339	Best loss: 0.095959	Accuracy: 97.81%
\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/truncated_normal/mean&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/truncated_normal/stddev&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.040601685643196106\n      }\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/truncated_normal/TruncatedNormal&quot;\n  op: &quot;TruncatedNormal&quot;\n  input: &quot;hidden1/kernel/Initializer/truncated_normal/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 42\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 7\n    }\n  }\n}\nnode {\n  name: &quot;hidden1/kernel/Initializer/truncated_normal/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;hidden1/kernel/Initializer/truncated_normal/TruncatedNormal&quot;\n  input: &quot;hidden1/kernel/Initializer/truncated_normal/stddev&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@hidden1/kernel&quot ...

# %% [markdown]
# ## Problem 9

# %%
reset_graph()

saver = tf.train.import_meta_graph("./dnn11_0_to_4.ckpt.meta")

# %%
for op in tf.get_default_graph().get_operations():
    print(op.name)
# Out:
# X
# y
# dnn/training/input
# dnn/training
# hidden1/kernel/Initializer/truncated_normal/shape
# hidden1/kernel/Initializer/truncated_normal/mean
# hidden1/kernel/Initializer/truncated_normal/stddev
# hidden1/kernel/Initializer/truncated_normal/TruncatedNormal
# hidden1/kernel/Initializer/truncated_normal/mul
# hidden1/kernel/Initializer/truncated_normal
# hidden1/kernel
# hidden1/kernel/Assign
# hidden1/kernel/read
# hidden1/bias/Initializer/zeros
# hidden1/bias
# hidden1/bias/Assign
# hidden1/bias/read
# dnn/hidden1/MatMul
# dnn/hidden1/BiasAdd
# dnn/hidden1/Elu
# hidden1/gamma/Initializer/ones
# hidden1/gamma
# hidden1/gamma/Assign
# hidden1/gamma/read
# hidden1/beta/Initializer/zeros
# hidden1/beta
# hidden1/beta/Assign
# hidden1/beta/read
# hidden1/moving_mean/Initializer/zeros
# hidden1/moving_mean
# hidden1/moving_mean/Assign
# hidden1/moving_mean/read
# hidden1/moving_variance/Initializer/ones
# hidden1/moving_variance
# hidden1/moving_variance/Assign
# hidden1/moving_variance/read
# dnn/hidden1_1/moments/mean/reduction_indices
# dnn/hidden1_1/moments/mean
# dnn/hidden1_1/moments/StopGradient
# dnn/hidden1_1/moments/SquaredDifference
# dnn/hidden1_1/moments/variance/reduction_indices
# dnn/hidden1_1/moments/variance
# dnn/hidden1_1/moments/Squeeze
# dnn/hidden1_1/moments/Squeeze_1
# dnn/hidden1_1/cond/Switch
# dnn/hidden1_1/cond/switch_t
# dnn/hidden1_1/cond/switch_f
# dnn/hidden1_1/cond/pred_id
# dnn/hidden1_1/cond/Switch_1
# dnn/hidden1_1/cond/Switch_2
# dnn/hidden1_1/cond/Merge
# dnn/hidden1_1/cond_1/Switch
# dnn/hidden1_1/cond_1/switch_t
# dnn/hidden1_1/cond_1/switch_f
# dnn/hidden1_1/cond_1/pred_id
# dnn/hidden1_1/cond_1/Switch_1
# dnn/hidden1_1/cond_1/Switch_2
# dnn/hidden1_1/cond_1/Merge
# dnn/hidden1_1/cond_2/Switch
# dnn/hidden1_1/cond_2/switch_t
# dnn/hidden1_1/cond_2/switch_f
# dnn/hidden1_1/cond_2/pred_id
# dnn/hidden1_1/cond_2/AssignMovingAvg/decay
# dnn/hidden1_1/cond_2/AssignMovingAvg/sub/Switch
# dnn/hidden1_1/cond_2/AssignMovingAvg/sub/Switch_1
# dnn/hidden1_1/cond_2/AssignMovingAvg/sub
# dnn/hidden1_1/cond_2/AssignMovingAvg/mul
# dnn/hidden1_1/cond_2/AssignMovingAvg/Switch
# dnn/hidden1_1/cond_2/AssignMovingAvg
# dnn/hidden1_1/cond_2/Switch_1
# dnn/hidden1_1/cond_2/Merge
# dnn/hidden1_1/cond_3/Switch
# dnn/hidden1_1/cond_3/switch_t
# dnn/hidden1_1/cond_3/switch_f
# dnn/hidden1_1/cond_3/pred_id
# dnn/hidden1_1/cond_3/AssignMovingAvg/decay
# dnn/hidden1_1/cond_3/AssignMovingAvg/sub/Switch
# dnn/hidden1_1/cond_3/AssignMovingAvg/sub/Switch_1
# dnn/hidden1_1/cond_3/AssignMovingAvg/sub
# dnn/hidden1_1/cond_3/AssignMovingAvg/mul
# dnn/hidden1_1/cond_3/AssignMovingAvg/Switch
# dnn/hidden1_1/cond_3/AssignMovingAvg
# dnn/hidden1_1/cond_3/Switch_1
# dnn/hidden1_1/cond_3/Merge
# dnn/hidden1_1/batchnorm/add/y
# dnn/hidden1_1/batchnorm/add
# dnn/hidden1_1/batchnorm/Rsqrt
# dnn/hidden1_1/batchnorm/mul
# dnn/hidden1_1/batchnorm/mul_1
# dnn/hidden1_1/batchnorm/mul_2
# dnn/hidden1_1/batchnorm/sub
# dnn/hidden1_1/batchnorm/add_1
# hidden2/kernel/Initializer/truncated_normal/shape
# hidden2/kernel/Initializer/truncated_normal/mean
# hidden2/kernel/Initializer/truncated_normal/stddev
# hidden2/kernel/Initializer/truncated_normal/TruncatedNormal
# hidden2/kernel/Initializer/truncated_normal/mul
# hidden2/kernel/Initializer/truncated_normal
# hidden2/kernel
# hidden2/kernel/Assign
# hidden2/kernel/read
# hidden2/bias/Initializer/zeros
# hidden2/bias
# hidden2/bias/Assign
# hidden2/bias/read
# dnn/hidden2/MatMul
# dnn/hidden2/BiasAdd
# dnn/hidden2/Elu
# hidden2/gamma/Initializer/ones
# hidden2/gamma
# hidden2/gamma/Assign
# hidden2/gamma/read
# hidden2/beta/Initializer/zeros
# hidden2/beta
# hidden2/beta/Assign
# hidden2/beta/read
# hidden2/moving_mean/Initializer/zeros
# hidden2/moving_mean
# hidden2/moving_mean/Assign
# hidden2/moving_mean/read
# hidden2/moving_variance/Initializer/ones
# hidden2/moving_variance
# hidden2/moving_variance/Assign
# hidden2/moving_variance/read
# dnn/hidden2_1/moments/mean/reduction_indices
# dnn/hidden2_1/moments/mean
# dnn/hidden2_1/moments/StopGradient
# dnn/hidden2_1/moments/SquaredDifference
# dnn/hidden2_1/moments/variance/reduction_indices
# dnn/hidden2_1/moments/variance
# dnn/hidden2_1/moments/Squeeze
# dnn/hidden2_1/moments/Squeeze_1
# dnn/hidden2_1/cond/Switch
# dnn/hidden2_1/cond/switch_t
# dnn/hidden2_1/cond/switch_f
# dnn/hidden2_1/cond/pred_id
# dnn/hidden2_1/cond/Switch_1
# dnn/hidden2_1/cond/Switch_2
# dnn/hidden2_1/cond/Merge
# dnn/hidden2_1/cond_1/Switch
# dnn/hidden2_1/cond_1/switch_t
# dnn/hidden2_1/cond_1/switch_f
# dnn/hidden2_1/cond_1/pred_id
# dnn/hidden2_1/cond_1/Switch_1
# dnn/hidden2_1/cond_1/Switch_2
# dnn/hidden2_1/cond_1/Merge
# dnn/hidden2_1/cond_2/Switch
# dnn/hidden2_1/cond_2/switch_t
# dnn/hidden2_1/cond_2/switch_f
# dnn/hidden2_1/cond_2/pred_id
# dnn/hidden2_1/cond_2/AssignMovingAvg/decay
# dnn/hidden2_1/cond_2/AssignMovingAvg/sub/Switch
# dnn/hidden2_1/cond_2/AssignMovingAvg/sub/Switch_1
# dnn/hidden2_1/cond_2/AssignMovingAvg/sub
# dnn/hidden2_1/cond_2/AssignMovingAvg/mul
# dnn/hidden2_1/cond_2/AssignMovingAvg/Switch
# dnn/hidden2_1/cond_2/AssignMovingAvg
# dnn/hidden2_1/cond_2/Switch_1
# dnn/hidden2_1/cond_2/Merge
# dnn/hidden2_1/cond_3/Switch
# dnn/hidden2_1/cond_3/switch_t
# dnn/hidden2_1/cond_3/switch_f
# dnn/hidden2_1/cond_3/pred_id
# dnn/hidden2_1/cond_3/AssignMovingAvg/decay
# dnn/hidden2_1/cond_3/AssignMovingAvg/sub/Switch
# dnn/hidden2_1/cond_3/AssignMovingAvg/sub/Switch_1
# dnn/hidden2_1/cond_3/AssignMovingAvg/sub
# dnn/hidden2_1/cond_3/AssignMovingAvg/mul
# dnn/hidden2_1/cond_3/AssignMovingAvg/Switch
# dnn/hidden2_1/cond_3/AssignMovingAvg
# dnn/hidden2_1/cond_3/Switch_1
# dnn/hidden2_1/cond_3/Merge
# dnn/hidden2_1/batchnorm/add/y
# dnn/hidden2_1/batchnorm/add
# dnn/hidden2_1/batchnorm/Rsqrt
# dnn/hidden2_1/batchnorm/mul
# dnn/hidden2_1/batchnorm/mul_1
# dnn/hidden2_1/batchnorm/mul_2
# dnn/hidden2_1/batchnorm/sub
# dnn/hidden2_1/batchnorm/add_1
# hidden3/kernel/Initializer/truncated_normal/shape
# hidden3/kernel/Initializer/truncated_normal/mean
# hidden3/kernel/Initializer/truncated_normal/stddev
# hidden3/kernel/Initializer/truncated_normal/TruncatedNormal
# hidden3/kernel/Initializer/truncated_normal/mul
# hidden3/kernel/Initializer/truncated_normal
# hidden3/kernel
# hidden3/kernel/Assign
# hidden3/kernel/read
# hidden3/bias/Initializer/zeros
# hidden3/bias
# hidden3/bias/Assign
# hidden3/bias/read
# dnn/hidden3/MatMul
# dnn/hidden3/BiasAdd
# dnn/hidden3/Elu
# hidden3/gamma/Initializer/ones
# hidden3/gamma
# hidden3/gamma/Assign
# hidden3/gamma/read
# hidden3/beta/Initializer/zeros
# hidden3/beta
# hidden3/beta/Assign
# hidden3/beta/read
# hidden3/moving_mean/Initializer/zeros
# hidden3/moving_mean
# hidden3/moving_mean/Assign
# hidden3/moving_mean/read
# hidden3/moving_variance/Initializer/ones
# hidden3/moving_variance
# hidden3/moving_variance/Assign
# hidden3/moving_variance/read
# dnn/hidden3_1/moments/mean/reduction_indices
# dnn/hidden3_1/moments/mean
# dnn/hidden3_1/moments/StopGradient
# dnn/hidden3_1/moments/SquaredDifference
# dnn/hidden3_1/moments/variance/reduction_indices
# dnn/hidden3_1/moments/variance
# hidden4/gamma
# hidden4/gamma/Assign
# hidden4/gamma/read
# hidden4/beta/Initializer/zeros
# hidden4/beta
# hidden4/beta/Assign
# hidden4/beta/read
# hidden4/moving_mean/Initializer/zeros
# hidden4/moving_mean
# hidden4/moving_mean/Assign
# hidden4/moving_mean/read
# hidden4/moving_variance/Initializer/ones
# hidden4/moving_variance
# hidden4/moving_variance/Assign
# hidden4/moving_variance/read
# dnn/hidden4_1/moments/mean/reduction_indices
# dnn/hidden4_1/moments/mean
# dnn/hidden4_1/moments/StopGradient
# dnn/hidden4_1/moments/SquaredDifference
# dnn/hidden4_1/moments/variance/reduction_indices
# dnn/hidden4_1/moments/variance
# dnn/hidden4_1/moments/Squeeze
# dnn/hidden4_1/moments/Squeeze_1
# dnn/hidden4_1/cond/Switch
# dnn/hidden4_1/cond/switch_t
# dnn/hidden4_1/cond/switch_f
# dnn/hidden4_1/cond/pred_id
# dnn/hidden4_1/cond/Switch_1
# dnn/hidden4_1/cond/Switch_2
# dnn/hidden4_1/cond/Merge
# dnn/hidden4_1/cond_1/Switch
# dnn/hidden4_1/cond_1/switch_t
# dnn/hidden4_1/cond_1/switch_f
# dnn/hidden4_1/cond_1/pred_id
# dnn/hidden4_1/cond_1/Switch_1
# dnn/hidden4_1/cond_1/Switch_2
# dnn/hidden4_1/cond_1/Merge
# dnn/hidden4_1/cond_2/Switch
# dnn/hidden4_1/cond_2/switch_t
# dnn/hidden4_1/cond_2/switch_f
# dnn/hidden4_1/cond_2/pred_id
# dnn/hidden4_1/cond_2/AssignMovingAvg/decay
# dnn/hidden4_1/cond_2/AssignMovingAvg/sub/Switch
# dnn/hidden4_1/cond_2/AssignMovingAvg/sub/Switch_1
# dnn/hidden4_1/cond_2/AssignMovingAvg/sub
# dnn/hidden4_1/cond_2/AssignMovingAvg/mul
# dnn/hidden4_1/cond_2/AssignMovingAvg/Switch
# dnn/hidden4_1/cond_2/AssignMovingAvg
# dnn/hidden4_1/cond_2/Switch_1
# dnn/hidden4_1/cond_2/Merge
# dnn/hidden4_1/cond_3/Switch
# dnn/hidden4_1/cond_3/switch_t
# dnn/hidden4_1/cond_3/switch_f
# dnn/hidden4_1/cond_3/pred_id
# dnn/hidden4_1/cond_3/AssignMovingAvg/decay
# dnn/hidden4_1/cond_3/AssignMovingAvg/sub/Switch
# dnn/hidden4_1/cond_3/AssignMovingAvg/sub/Switch_1
# dnn/hidden4_1/cond_3/AssignMovingAvg/sub
# dnn/hidden4_1/cond_3/AssignMovingAvg/mul
# dnn/hidden4_1/cond_3/AssignMovingAvg/Switch
# dnn/hidden4_1/cond_3/AssignMovingAvg
# dnn/hidden4_1/cond_3/Switch_1
# dnn/hidden4_1/cond_3/Merge
# dnn/hidden4_1/batchnorm/add/y
# dnn/hidden4_1/batchnorm/add
# dnn/hidden4_1/batchnorm/Rsqrt
# dnn/hidden4_1/batchnorm/mul
# dnn/hidden4_1/batchnorm/mul_1
# dnn/hidden4_1/batchnorm/mul_2
# dnn/hidden4_1/batchnorm/sub
# dnn/hidden4_1/batchnorm/add_1
# hidden5/kernel/Initializer/truncated_normal/shape
# hidden5/kernel/Initializer/truncated_normal/mean
# hidden5/kernel/Initializer/truncated_normal/stddev
# hidden5/kernel/Initializer/truncated_normal/TruncatedNormal
# hidden5/kernel/Initializer/truncated_normal/mul
# hidden5/kernel/Initializer/truncated_normal
# hidden5/kernel
# hidden5/kernel/Assign
# hidden5/kernel/read
# hidden5/bias/Initializer/zeros
# hidden5/bias
# hidden5/bias/Assign
# hidden5/bias/read
# dnn/hidden5/MatMul
# dnn/hidden5/BiasAdd
# dnn/hidden5/Elu
# hidden5/gamma/Initializer/ones
# hidden5/gamma
# hidden5/gamma/Assign
# hidden5/gamma/read
# hidden5/beta/Initializer/zeros
# hidden5/beta
# hidden5/beta/Assign
# hidden5/beta/read
# hidden5/moving_mean/Initializer/zeros
# hidden5/moving_mean
# hidden5/moving_mean/Assign
# hidden5/moving_mean/read
# hidden5/moving_variance/Initializer/ones
# hidden5/moving_variance
# hidden5/moving_variance/Assign
# hidden5/moving_variance/read
# dnn/hidden5_1/moments/mean/reduction_indices
# dnn/hidden5_1/moments/mean
# dnn/hidden5_1/moments/StopGradient
# dnn/hidden5_1/moments/SquaredDifference
# dnn/hidden5_1/moments/variance/reduction_indices
# dnn/hidden5_1/moments/variance
# dnn/hidden5_1/moments/Squeeze
# dnn/hidden5_1/moments/Squeeze_1
# dnn/hidden5_1/cond/Switch
# dnn/hidden5_1/cond/switch_t
# dnn/hidden5_1/cond/switch_f
# dnn/hidden5_1/cond/pred_id
# dnn/hidden5_1/cond/Switch_1
# dnn/hidden5_1/cond/Switch_2
# dnn/hidden5_1/cond/Merge
# dnn/hidden5_1/cond_1/Switch
# dnn/hidden5_1/cond_1/switch_t
# dnn/hidden5_1/cond_1/switch_f
# dnn/hidden5_1/cond_1/pred_id
# dnn/hidden5_1/cond_1/Switch_1
# dnn/hidden5_1/cond_1/Switch_2
# dnn/hidden5_1/cond_1/Merge
# dnn/hidden5_1/cond_2/Switch
# dnn/hidden5_1/cond_2/switch_t
# dnn/hidden5_1/cond_2/switch_f
# dnn/hidden5_1/cond_2/pred_id
# dnn/hidden5_1/cond_2/AssignMovingAvg/decay
# dnn/hidden5_1/cond_2/AssignMovingAvg/sub/Switch
# dnn/hidden5_1/cond_2/AssignMovingAvg/sub/Switch_1
# dnn/hidden5_1/cond_2/AssignMovingAvg/sub
# dnn/hidden5_1/cond_2/AssignMovingAvg/mul
# dnn/hidden5_1/cond_2/AssignMovingAvg/Switch
# dnn/hidden5_1/cond_2/AssignMovingAvg
# dnn/hidden5_1/cond_2/Switch_1
# dnn/hidden5_1/cond_2/Merge
# dnn/hidden5_1/cond_3/Switch
# dnn/hidden5_1/cond_3/switch_t
# dnn/hidden5_1/cond_3/switch_f
# dnn/hidden5_1/cond_3/pred_id
# dnn/hidden5_1/cond_3/AssignMovingAvg/decay
# dnn/hidden5_1/cond_3/AssignMovingAvg/sub/Switch
# dnn/hidden5_1/cond_3/AssignMovingAvg/sub/Switch_1
# dnn/hidden5_1/cond_3/AssignMovingAvg/sub
# dnn/hidden5_1/cond_3/AssignMovingAvg/mul
# dnn/hidden5_1/cond_3/AssignMovingAvg/Switch
# dnn/hidden5_1/cond_3/AssignMovingAvg
# dnn/hidden5_1/cond_3/Switch_1
# dnn/hidden5_1/cond_3/Merge
# dnn/hidden5_1/batchnorm/add/y
# dnn/hidden5_1/batchnorm/add
# dnn/hidden5_1/batchnorm/Rsqrt
# dnn/hidden5_1/batchnorm/mul
# dnn/hidden5_1/batchnorm/mul_1
# dnn/hidden5_1/batchnorm/mul_2
# dnn/hidden5_1/batchnorm/sub
# dnn/hidden5_1/batchnorm/add_1
# logits/kernel/Initializer/truncated_normal/shape
# logits/kernel/Initializer/truncated_normal/mean
# logits/kernel/Initializer/truncated_normal/stddev
# logits/kernel/Initializer/truncated_normal/TruncatedNormal
# logits/kernel/Initializer/truncated_normal/mul
# logits/kernel/Initializer/truncated_normal
# logits/kernel
# logits/kernel/Assign
# logits/kernel/read
# logits/bias/Initializer/zeros
# logits/bias
# logits/bias/Assign
# logits/bias/read
# dnn/logits/MatMul
# dnn/logits/BiasAdd
# dnn/y_prob
# loss/SparseSoftmaxCrossEntropyWithLogits/Shape
# loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits
# loss/Const
# loss/loss
# train/gradients/Shape
# train/gradients/grad_ys_0
# train/gradients/Fill
# train/gradients/loss/loss_grad/Reshape/shape
# train/gradients/loss/loss_grad/Reshape
# train/gradients/loss/loss_grad/Shape
# train/gradients/loss/loss_grad/Tile
# train/gradients/loss/loss_grad/Shape_1
# train/gradients/loss/loss_grad/Shape_2
# train/gradients/loss/loss_grad/Const
# train/gradients/loss/loss_grad/Prod
# train/gradients/loss/loss_grad/Const_1
# train/gradients/loss/loss_grad/Prod_1
# train/gradients/loss/loss_grad/Maximum/y
# train/gradients/loss/loss_grad/Maximum
# train/gradients/loss/loss_grad/floordiv
# train/gradients/loss/loss_grad/Cast
# train/gradients/loss/loss_grad/truediv
# train/gradients/zeros_like
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/PreventGradient
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/ExpandDims
# train/gradients/loss/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits_grad/mul
# train/gradients/dnn/logits/BiasAdd_grad/BiasAddGrad
# train/gradients/dnn/logits/BiasAdd_grad/tuple/group_deps
# train/gradients/dnn/logits/BiasAdd_grad/tuple/control_dependency
# train/gradients/dnn/logits/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/dnn/logits/MatMul_grad/MatMul
# train/gradients/dnn/logits/MatMul_grad/MatMul_1
# train/gradients/dnn/logits/MatMul_grad/tuple/group_deps
# train/gradients/dnn/logits/MatMul_grad/tuple/control_dependency
# train/gradients/dnn/logits/MatMul_grad/tuple/control_dependency_1
# train/gradients/dnn/hidden5_1/batchnorm/add_1_grad/Shape
# train/gradients/dnn/hidden5_1/batchnorm/add_1_grad/Shape_1
# train/gradients/dnn/hidden5_1/batchnorm/add_1_grad/BroadcastGradientArgs
# train/gradients/dnn/hidden5_1/batchnorm/add_1_grad/Sum
# train/gradients/dnn/hidden5_1/batchnorm/add_1_grad/Reshape
# train/gradients/dnn/hidden5_1/batchnorm/add_1_grad/Sum_1
# train/gradients/dnn/hidden5_1/batchnorm/add_1_grad/Reshape_1
# train/gradients/dnn/hidden5_1/batchnorm/add_1_grad/tuple/group_deps
# train/gradients/dnn/hidden5_1/batchnorm/add_1_grad/tuple/control_dependency
# train/gradients/dnn/hidden5_1/batchnorm/add_1_grad/tuple/control_dependency_1
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/Shape
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/Shape_1
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/BroadcastGradientArgs
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/Mul
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/Sum
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/Reshape
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/Mul_1
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/Sum_1
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/Reshape_1
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/tuple/group_deps
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/tuple/control_dependency
# train/gradients/dnn/hidden5_1/batchnorm/mul_1_grad/tuple/control_dependency_1
# train/gradients/dnn/hidden5_1/batchnorm/sub_grad/Neg
# train/gradients/dnn/hidden5_1/batchnorm/sub_grad/tuple/group_deps
# train/gradients/dnn/hidden5_1/batchnorm/sub_grad/tuple/control_dependency
# train/gradients/dnn/hidden5_1/batchnorm/sub_grad/tuple/control_dependency_1
# train/gradients/dnn/hidden5_1/batchnorm/mul_2_grad/Mul
# train/gradients/dnn/hidden5_1/batchnorm/mul_2_grad/Mul_1
# train/gradients/dnn/hidden5_1/batchnorm/mul_2_grad/tuple/group_deps
# train/gradients/dnn/hidden5_1
grad/tuple/control_dependency_1
# train/gradients/dnn/hidden3/Elu_grad/EluGrad
# train/gradients/dnn/hidden3/BiasAdd_grad/BiasAddGrad
# train/gradients/dnn/hidden3/BiasAdd_grad/tuple/group_deps
# train/gradients/dnn/hidden3/BiasAdd_grad/tuple/control_dependency
# train/gradients/dnn/hidden3/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/dnn/hidden3/MatMul_grad/MatMul
# train/gradients/dnn/hidden3/MatMul_grad/MatMul_1
# train/gradients/dnn/hidden3/MatMul_grad/tuple/group_deps
# train/gradients/dnn/hidden3/MatMul_grad/tuple/control_dependency
# train/gradients/dnn/hidden3/MatMul_grad/tuple/control_dependency_1
# train/gradients/dnn/hidden2/Elu_grad/EluGrad
# train/gradients/dnn/hidden2/BiasAdd_grad/BiasAddGrad
# train/gradients/dnn/hidden2/BiasAdd_grad/tuple/group_deps
# train/gradients/dnn/hidden2/BiasAdd_grad/tuple/control_dependency
# train/gradients/dnn/hidden2/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/dnn/hidden2/MatMul_grad/MatMul
# train/gradients/dnn/hidden2/MatMul_grad/MatMul_1
# train/gradients/dnn/hidden2/MatMul_grad/tuple/group_deps
# train/gradients/dnn/hidden2/MatMul_grad/tuple/control_dependency
# train/gradients/dnn/hidden2/MatMul_grad/tuple/control_dependency_1
# train/gradients/dnn/hidden1/Elu_grad/EluGrad
# train/gradients/dnn/hidden1/BiasAdd_grad/BiasAddGrad
# train/gradients/dnn/hidden1/BiasAdd_grad/tuple/group_deps
# train/gradients/dnn/hidden1/BiasAdd_grad/tuple/control_dependency
# train/gradients/dnn/hidden1/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/dnn/hidden1/MatMul_grad/MatMul
# train/gradients/dnn/hidden1/MatMul_grad/MatMul_1
# train/gradients/dnn/hidden1/MatMul_grad/tuple/group_deps
# train/gradients/dnn/hidden1/MatMul_grad/tuple/control_dependency
# train/gradients/dnn/hidden1/MatMul_grad/tuple/control_dependency_1
# train/beta1_power/initial_value
# train/beta1_power
# train/beta1_power/Assign
# train/beta1_power/read
# train/beta2_power/initial_value
# train/beta2_power
# train/beta2_power/Assign
# train/beta2_power/read
# hidden1/kernel/Adam/Initializer/zeros/shape_as_tensor
# hidden1/kernel/Adam/Initializer/zeros/Const
# hidden1/kernel/Adam/Initializer/zeros
# hidden1/kernel/Adam
# hidden1/kernel/Adam/Assign
# hidden1/kernel/Adam/read
# hidden1/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# hidden1/kernel/Adam_1/Initializer/zeros/Const
# hidden1/kernel/Adam_1/Initializer/zeros
# hidden1/kernel/Adam_1
# hidden1/kernel/Adam_1/Assign
# hidden1/kernel/Adam_1/read
# hidden1/bias/Adam/Initializer/zeros
# hidden1/bias/Adam
# hidden1/bias/Adam/Assign
# hidden1/bias/Adam/read
# hidden1/bias/Adam_1/Initializer/zeros
# hidden1/bias/Adam_1
# hidden1/bias/Adam_1/Assign
# hidden1/bias/Adam_1/read
# hidden2/kernel/Adam/Initializer/zeros/shape_as_tensor
# hidden2/kernel/Adam/Initializer/zeros/Const
# hidden2/kernel/Adam/Initializer/zeros
# hidden2/kernel/Adam
# hidden2/kernel/Adam/Assign
# hidden2/kernel/Adam/read
# hidden2/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# hidden2/kernel/Adam_1/Initializer/zeros/Const
# hidden2/kernel/Adam_1/Initializer/zeros
# hidden2/kernel/Adam_1
# hidden2/kernel/Adam_1/Assign
# hidden2/kernel/Adam_1/read
# hidden2/bias/Adam/Initializer/zeros
# hidden2/bias/Adam
# hidden2/bias/Adam/Assign
# hidden2/bias/Adam/read
# hidden2/bias/Adam_1/Initializer/zeros
# hidden2/bias/Adam_1
# hidden2/bias/Adam_1/Assign
# hidden2/bias/Adam_1/read
# hidden3/kernel/Adam/Initializer/zeros/shape_as_tensor
# hidden3/kernel/Adam/Initializer/zeros/Const
# hidden3/kernel/Adam/Initializer/zeros
# hidden3/kernel/Adam
# hidden3/kernel/Adam/Assign
# hidden3/kernel/Adam/read
# hidden3/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# hidden3/kernel/Adam_1/Initializer/zeros/Const
# hidden3/kernel/Adam_1/Initializer/zeros
# hidden3/kernel/Adam_1
# hidden3/kernel/Adam_1/Assign
# hidden3/kernel/Adam_1/read
# hidden3/bias/Adam/Initializer/zeros
# hidden3/bias/Adam
# hidden3/bias/Adam/Assign
# hidden3/bias/Adam/read
# hidden3/bias/Adam_1/Initializer/zeros
# hidden3/bias/Adam_1
# hidden3/bias/Adam_1/Assign
# hidden3/bias/Adam_1/read
# hidden4/kernel/Adam/Initializer/zeros/shape_as_tensor
# hidden4/kernel/Adam/Initializer/zeros/Const
# hidden4/kernel/Adam/Initializer/zeros
# hidden4/kernel/Adam
# hidden4/kernel/Adam/Assign
# hidden4/kernel/Adam/read
# hidden4/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# hidden4/kernel/Adam_1/Initializer/zeros/Const
# hidden4/kernel/Adam_1/Initializer/zeros
# hidden4/kernel/Adam_1
# hidden4/kernel/Adam_1/Assign
# hidden4/kernel/Adam_1/read
# hidden4/bias/Adam/Initializer/zeros
# hidden4/bias/Adam
# hidden4/bias/Adam/Assign
# hidden4/bias/Adam/read
# hidden4/bias/Adam_1/Initializer/zeros
# hidden4/bias/Adam_1
# hidden4/bias/Adam_1/Assign
# hidden4/bias/Adam_1/read
# hidden5/kernel/Adam/Initializer/zeros/shape_as_tensor
# hidden5/kernel/Adam/Initializer/zeros/Const
# hidden5/kernel/Adam/Initializer/zeros
# hidden5/kernel/Adam
# hidden5/kernel/Adam/Assign
# hidden5/kernel/Adam/read
# hidden5/kernel/Adam_1/Initializer/zeros/shape_as_tensor
# hidden5/kernel/Adam_1/Initializer/zeros/Const
# hidden5/kernel/Adam_1/Initializer/zeros
# hidden5/kernel/Adam_1
# hidden5/kernel/Adam_1/Assign
# hidden5/kernel/Adam_1/read
# hidden5/bias/Adam/Initializer/zeros
# hidden5/bias/Adam
# hidden5/bias/Adam/Assign
# hidden5/bias/Adam/read
# hidden5/bias/Adam_1/Initializer/zeros
# hidden5/bias/Adam_1
# hidden5/bias/Adam_1/Assign
# hidden5/bias/Adam_1/read
# hidden5/gamma/Adam/Initializer/zeros
# hidden5/gamma/Adam
# hidden5/gamma/Adam/Assign
# hidden5/gamma/Adam/read
# hidden5/gamma/Adam_1/Initializer/zeros
# hidden5/gamma/Adam_1
# hidden5/gamma/Adam_1/Assign
# hidden5/gamma/Adam_1/read
# hidden5/beta/Adam/Initializer/zeros
# hidden5/beta/Adam
# hidden5/beta/Adam/Assign
# hidden5/beta/Adam/read
# hidden5/beta/Adam_1/Initializer/zeros
# hidden5/beta/Adam_1
# hidden5/beta/Adam_1/Assign
# hidden5/beta/Adam_1/read
# logits/kernel/Adam/Initializer/zeros
# logits/kernel/Adam
# logits/kernel/Adam/Assign
# logits/kernel/Adam/read
# logits/kernel/Adam_1/Initializer/zeros
# logits/kernel/Adam_1
# logits/kernel/Adam_1/Assign
# logits/kernel/Adam_1/read
# logits/bias/Adam/Initializer/zeros
# logits/bias/Adam
# logits/bias/Adam/Assign
# logits/bias/Adam/read
# logits/bias/Adam_1/Initializer/zeros
# logits/bias/Adam_1
# logits/bias/Adam_1/Assign
# logits/bias/Adam_1/read
# train/training_op/learning_rate
# train/training_op/beta1
# train/training_op/beta2
# train/training_op/epsilon
# train/training_op/update_hidden1/kernel/ApplyAdam
# train/training_op/update_hidden1/bias/ApplyAdam
# train/training_op/update_hidden2/kernel/ApplyAdam
# train/training_op/update_hidden2/bias/ApplyAdam
# train/training_op/update_hidden3/kernel/ApplyAdam
# train/training_op/update_hidden3/bias/ApplyAdam
# train/training_op/update_hidden4/kernel/ApplyAdam
# train/training_op/update_hidden4/bias/ApplyAdam
# train/training_op/update_hidden5/kernel/ApplyAdam
# train/training_op/update_hidden5/bias/ApplyAdam
# train/training_op/update_hidden5/gamma/ApplyAdam
# train/training_op/update_hidden5/beta/ApplyAdam
# train/training_op/update_logits/kernel/ApplyAdam
# train/training_op/update_logits/bias/ApplyAdam
# train/training_op/mul
# train/training_op/Assign
# train/training_op/mul_1
# train/training_op/Assign_1
# train/training_op
# train/log_loss/tags
# train/log_loss
# eval/in_top_k/InTopKV2/k
# eval/in_top_k/InTopKV2
# eval/Cast
# eval/Const
# eval/Mean
# init/init
# save/save/Const
# save/save/SaveV2/tensor_names
# save/save/SaveV2/shape_and_slices
# save/save/SaveV2
# save/save/control_dependency
# save/save/RestoreV2/tensor_names
# save/save/RestoreV2/shape_and_slices
# save/save/RestoreV2
# save/save/Assign
# save/save/Assign_1
# save/save/Assign_2
# save/save/Assign_3
# save/save/Assign_4
# save/save/Assign_5
# save/save/Assign_6
# save/save/Assign_7
# save/save/Assign_8
# save/save/Assign_9
# save/save/Assign_10
# save/save/Assign_11
# save/save/Assign_12
# save/save/Assign_13
# save/save/Assign_14
# save/save/Assign_15
# save/save/Assign_16
# save/save/Assign_17
# save/save/Assign_18
# save/save/Assign_19
# save/save/Assign_20
# save/save/Assign_21
# save/save/Assign_22
# save/save/Assign_23
# save/save/Assign_24
# save/save/Assign_25
# save/save/Assign_26
# save/save/Assign_27
# save/save/Assign_28
# save/save/Assign_29
# save/save/Assign_30
# save/save/Assign_31
# save/save/Assign_32
# save/save/Assign_33
# save/save/Assign_34
# save/save/Assign_35
# save/save/Assign_36
# save/save/Assign_37
# save/save/Assign_38
# save/save/Assign_39
# save/save/Assign_40
# save/save/Assign_41
# save/save/Assign_42
# save/save/Assign_43
# save/save/Assign_44
# save/save/Assign_45
# save/save/Assign_46
# save/save/Assign_47
# save/save/Assign_48
# save/save/Assign_49
# save/save/Assign_50
# save/save/Assign_51
# save/save/Assign_52
# save/save/Assign_53
# save/save/Assign_54
# save/save/Assign_55
# save/save/Assign_56
# save/save/Assign_57
# save/save/Assign_58
# save/save/Assign_59
# save/save/Assign_60
# save/save/Assign_61
# save/save/restore_all
